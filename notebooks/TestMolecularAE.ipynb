# %%
import numpy as np

import matplotlib as mp
mp.use('nbagg')
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")

# %%
loss = np.array([])
for i in range(10):
    loss = np.append(loss, np.load('../Pilot2/P2B1/moleAE_results/01032018_160141/epoch_' + str(i) + '/loss.npy'))
len(loss)
# Out:
# 2400

# %%
#plt.subplot(211)
plt.semilogy(loss)
plt.xticks(range(0,len(loss)+1,400))
plt.xlabel('Frames')
plt.title('Loss')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1040">

# %%
loss = np.array([])
for i in range(1):
    loss = np.append(loss, np.load('Pilot2/P2B1/moleAE_results/12182017_run16_long_conv_incl_8/epoch_' + str(i) + '/loss.npy'))
len(loss)
# Out:
# 120

# %%
#plt.subplot(211)
plt.semilogy(loss)
plt.xticks(range(0,361,120))
plt.xlabel('Frames')
plt.title('Loss')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1040">

# %%
#loss = np.load('Pilot2/P2B1/moleAE_results/12122017_only/epoch_2/loss.npy')
data = np.load('../Pilot2/P2B1/moleAE_results/01032018_160141/epoch_0/3k_run16_\
10us.35fs-DPPC.20-DIPC.60-CHOL.20_chunk_11_outof_29_AE_IncludeTrue_ConvTrue.npy')

data = np.squeeze(data)
ind = np.random.randint(30)
print ind
data = data[ind,:,:]

#plt.subplot(212)
plt.plot(data, linewidth=1)
plt.xlabel('Molecule number')
plt.title('Latent space')
plt.show()
# Out:
# 8
# <img src="data:image/png;base64,..." width="1040">

# %%
data.shape
# Out:
# (3040, 8)

# %%
test = data.reshape(data.shape[0],4,-1)

# %%
test.shape
# Out:
# (3040, 4, 2)
