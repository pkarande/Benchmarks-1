# %%
import numpy as np
import matplotlib as mp
mp.use('nbagg')
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('ticks')
sns.set_context('paper')

# %%
# Load and plot the loss function
loss = np.array([])
for i in range(9):
    loss = np.append(loss, np.load('../Pilot2/P2B1/moleAE_results/02062018_143242_rel_slwer/epoch_' + str(i) + '/loss.npy'))
print len(loss)

#plt.subplot(211)
plt.semilogy(loss)
plt.xticks(range(0,len(loss)+1,400))
plt.xlabel('Frames')
plt.title('Loss')
sns.despine()
plt.show()
# Out:
# 2700
# <img src="data:image/png;base64,..." width="639.6499809369451">

# %%
# Load and plot the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

data = np.load('../Pilot2/P2B1/moleAE_results/02062018_143242_rel_slwer/epoch_4/3k_run16_\
10us.35fs-DPPC.20-DIPC.60-CHOL.20_chunk_15_outof_29_AE_IncludeTrue_ConvTrue.npy')
print data.shape
data = np.squeeze(data)
ind = 30 # np.random.randint(30)
print ind
data = data[ind,:,:]
norm_feats = scaler.fit_transform(data)

#plt.subplot(212)
plt.plot(norm_feats, linewidth=1)
plt.xlabel('Molecule number')
plt.title('Latent space')
plt.show()
# Out:
# (100, 3040, 8)
# 30
# <img src="data:image/png;base64,..." width="639.6499809369451">

# %%
plt.title('Latent space')
for i in range(8):
    plt.subplot(8, 1, i+1)
    plt.plot(norm_feats[:,i], linewidth=1)
    plt.yticks([])
    sns.despine()
plt.yticks([0, 1])
plt.xlabel('Molecule number')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.6499809369451">

# %% [markdown]
# # Test the Latent space output
# 1. Visulalize how the latent space output depends on the molecule type. Just realized, you will need to use the other npz file I shared to get the molecule type. The indexing of the molecules is same, irrespective of the chunk or frame. So you can use the same data.
# 2. The output is saved for different epochs and each epoch has a chunk of data. There should be 30 frames in each chunk and the chunks are ordered. Visulaize and track the latent space output of a give molecule across frames. There are frame gaps across chunks but that can be ignored for now.
